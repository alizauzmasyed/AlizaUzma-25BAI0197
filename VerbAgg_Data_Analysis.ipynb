# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/VerbAgg.csv')

# %%
df.sample(4)
# Out:
#                                                  img  \
# 87       /games/boxart/full_1882754JapanFrontccc.jpg
# 38419  /games/boxart/full_5716095AmericaFrontccc.jpg
# 34355    /games/boxart/full_9747592JapanFrontccc.jpg
# 34270                      /games/boxart/default.jpg
#
#                                          title console         genre  \
# 87                            Final Fantasy XV     PS4  Role-Playing
# 38419                        The Hula Hamsters      PC          Misc
# 34355  Family Mahjong II: Shanghai he no Michi     NES          Misc
# 34270               Escape Trick: Ninja Castle     DSi          Misc
#
#          publisher       developer  critic_score  total_sales  na_sales  \
# 87     Square Enix     Square Enix           8.1         5.07      1.81
# 38419   3A Studios  3A Studios Inc           NaN          NaN       NaN
# 34355        Namco    Nihon Bussan           NaN          NaN       NaN
# ...

# %%
df.columns
# Out:
# Index(['img', 'Title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'total_sales', 'na_sales', 'jp_sales', 'pal_sales',
#        'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %%
df.rename(columns={'title':'Heading'},inplace=True)

# %%
df.head()
# Out:
#                                              img                        Title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %%
df['Title'].value_counts()
# Out:
# Title
# Plants vs. Zombies                                            17
# Pac-Man                                                       16
# Monopoly                                                      15
# Doom                                                          14
# Double Dragon                                                 14
#                                                               ..
# Tlicolity Eyes: Twinkle Snowtime                               1
# The Mind's Eclipse                                             1
# The House in Fata Morgana: Dreams of the Revenants Edition     1
# The House in Fata Morgana: Dream of the Revenants Edition      1
# The Fox Is Waiting For Me                                      1
# Name: count, Length: 39798, dtype: int64

# %%
df.shape
# Out:
# (64016, 14)

# %%
df.isnull().sum()
# Out:
# img                 0
# Title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64
